# %%
# Programa que calcula a quantidade de cédulas necessárias para um saque.
# O valor informado pelo usuário é dividido nas maiores cédulas disponíveis (100, 50, 20, 10, 5 e 1).
# Ao final, o programa exibe a quantidade de cada cédula utilizada.

valor = int(input("Digite o valor em R$: "))

while True:
  if valor >= 100:
    cont100 = valor // 100
    valor = valor - cont100 * 100
    print(f"Cédulas de 100: {cont100}")
    if not valor:
      break

  if valor >= 50:
    cont50 = valor // 50
    valor = valor - cont50 * 50
    print(f"Cédulas de 50: {cont50}")
    if not valor:
      break

  if valor >= 20:
    cont20 = valor // 20
    valor = valor - cont20 * 20
    print(f"Cédulas de 20: {cont20}")
    if not valor:
      break

  if valor >= 10:
    cont10 = valor // 10
    valor = valor - cont10 * 10
    print(f"Cédulas de 10: {cont10}")
    if not valor:
      break

  if valor >= 5:
    cont5 = valor // 5
    valor = valor - cont5 * 5
    print(f"Cédulas de 5: {cont5}")
    if not valor:
      break

  if valor:
    con1 = valor
    print(f"Cédulas de 1: {con1}")
    break
# Out:
# Digite o valor em R$: 5000
# Cédulas de 100: 50
