# %% [markdown]
# Exercicios 1✨

# %%
# Programa que verifica se três lados formam um triângulo
# e classifica o triângulo como:
# - Equilátero
# - Isósceles
# - Escaleno

A = int(input('Digite o 1º lado do triângulo: '))
B = int(input('Digite o 2º lado do triângulo: '))
C = int(input('Digite o 3º lado do triângulo: '))

if (A > 0 and B > 0 and C > 0) and (A + B > C and A + C > B and B + C > A):

    if A == B and B == C:
        print('Triângulo equilátero!')

    elif A != B and A != C and B != C:
        print('Triângulo escaleno!')

    else:
        print('Triângulo isósceles!')

else:
    print('Ao menos um dos valores indicados  não servem para formar um triângulo.')
# Out:
# Digite o 1º lado do triângulo: 4
# Digite o 2º lado do triângulo: 6
# Digite o 3º lado do triângulo: 7
# Triângulo escaleno!
